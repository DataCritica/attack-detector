# %%
# !pipenv install sentence_transformers
# !pipenv install umap-learn
# !pipenv install hdbscan
# !pipenv install joblib==1.1.0
# Out:
# Installing sentence_transformers...
# Adding sentence_transformers to Pipfile's [packages]...
# ✔ Installation Succeeded
# Installing dependencies from Pipfile.lock (e17d89)...
#   🐍   ▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉ 0/0 — 00:00:00
# Installing umap-learn...
# Adding umap-learn to Pipfile's [packages]...
# ✔ Installation Succeeded
# Installing dependencies from Pipfile.lock (e17d89)...
#   🐍   ▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉ 0/0 — 00:00:00
# Usage: pipenv [OPTIONS] COMMAND [ARGS]...
# Try 'pipenv -h' for help.
#
# Error: No such option: --quietinstall Did you mean --quiet?
# Installing joblib==1.1.0...
# Adding joblib to Pipfile's [packages]...
# ✔ Installation Succeeded
# Installing dependencies from Pipfile.lock (e17d89)...
#   🐍   ▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉ 0/0 — 00:00:00

# %% [markdown]
# ### Imports

# %%
# General
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
# from tqdm import tqdm
# import plotly.graph_objects as go
import plotly.express as px

# Topic modeling
from sentence_transformers import SentenceTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
# from sklearn.feature_extraction.text import TfidfVectorizer
from umap import UMAP
# from sklearn.cluster import KMeans
from hdbscan import HDBSCAN

LANG = 'Portuguese'

# %% [markdown]
# ### Load data

# %%
data = pd.read_csv("../data/processed/tweets.csv")
# Filter tweets in Spanish
data = data.loc[data['Language'] == 'pt']
data.head()
# Out:
#                                                    Text Classification  \
# 1169  @Paollabrasil1 @CarlosBolsonaro Ele votou cont...            sim
# 1170  @LiaBolsonaro @eusoupetersen @CarlosBolsonaro ...            sim
# 1171  @martaserrat @jairbolsonaro @BolsonaroSP @Cris...            sim
# 1172  @EntreOutrasMil @CarlosBolsonaro Gostosa e bur...            sim
# 1173  @inesbalbino25 @CarlosBolsonaro Menina de deus...            sim
#
#      Language  Label
# 1169       pt      1
# 1170       pt      1
# 1171       pt      1
# 1172       pt      1
# 1173       pt      1

# %% [markdown]
# ### Process data

# %%
# Function to automate data cleasing
def regex_transforms(x):

  # Replace multiple symbols
  re_1 = re.sub("[^\w\d\s]{2,}", "", x)

  # Replace strings beginning with @
  re_2 = re.sub("@[\w]+", "", re_1)

  # Replace links
  re_3 = re.sub("http.+\s", "", re_2)

  # Replace "RT" token
  re_4 = re.sub("(?i)RT\s", "", re_3)

  # Replace numbers
  re_5 = re.sub("[\d]", "", re_4)

  # Replace whitespaces at the end
  re_6 = re.sub("\s?[\W]\s", " ", re_5)

  return re_6

def remove_sp_chars(x):
  pr_1 = x.translate(str.maketrans(""""~-_\&%#|""", 
                                   "         ")).split()
  pr_2 = " ".join(pr_1)

  return pr_2

# Apply function to data 
data["Text_Processed"] = data["Text"].apply(regex_transforms)
data["Text_Processed"] = data["Text_Processed"].apply(remove_sp_chars)

# Show data
data.head()
# Out:
#                                                    Text Classification  \
# 1169  @Paollabrasil1 @CarlosBolsonaro Ele votou cont...            sim
# 1170  @LiaBolsonaro @eusoupetersen @CarlosBolsonaro ...            sim
# 1171  @martaserrat @jairbolsonaro @BolsonaroSP @Cris...            sim
# 1172  @EntreOutrasMil @CarlosBolsonaro Gostosa e bur...            sim
# 1173  @inesbalbino25 @CarlosBolsonaro Menina de deus...            sim
#
#      Language  Label                                     Text_Processed
# 1169       pt      1  Ele votou contra o fundão que o bolsomico quer...
# 1170       pt      1                        Voce é burra ou é só má fé?
# 1171       pt      1  Mas os canalhas pegaram no pé dele mesmo É rid...
# 1172       pt      1                        Gostosa e burra perfeitinha
# 1173       pt      1  Menina de deus o que que tu tá fumando Você tá...

# %% [markdown]
# ### Embeddings

# %%
# Import algorithm to generate embeddings
sbert_model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
# Filter data cassified as hate speech
subset_hs = data[data["Label"] == 1]

# Process data with encoder
vecs = sbert_model.encode(subset_hs["Text_Processed"].values)

# %%
# Apply the dimensionality reduction process.

# Scaler to normalize data
scaler = StandardScaler()
# PCA to reduce multicollinearity and noise
pca_ = PCA(0.9, random_state=5)
# UMAP to reduce dimensionality to two components
umap_ = UMAP(n_components=2,
             random_state=5,
             metric="cosine",
             n_neighbors=50,
             min_dist=0.1)

vecs_sc = scaler.fit_transform(vecs)
vecs_pca = pca_.fit_transform(vecs_sc)
vecs_umap = umap_.fit_transform(vecs_pca)

# %%
# Assign components to dataset
subset_hs.loc[:,"COMP_1"] = vecs_umap[:,0]
subset_hs.loc[:,"COMP_2"] = vecs_umap[:,1]

# Show data
subset_hs.head()
# Out:
# /tmp/ipykernel_30810/303276436.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_hs.loc[:,"COMP_1"] = vecs_umap[:,0]
# /tmp/ipykernel_30810/303276436.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_hs.loc[:,"COMP_2"] = vecs_umap[:,1]
#                                                    Text Classification  \
# 1169  @Paollabrasil1 @CarlosBolsonaro Ele votou cont...            sim
# 1170  @LiaBolsonaro @eusoupetersen @CarlosBolsonaro ...            sim
# 1171  @martaserrat @jairbolsonaro @BolsonaroSP @Cris...            sim
# 1172  @EntreOutrasMil @CarlosBolsonaro Gostosa e bur...            sim
# 1173  @inesbalbino25 @CarlosBolsonaro Menina de deus...            sim
#
#      Language  Label                                     Text_Processed  \
# 1169       pt      1  Ele votou contra o fundão que o bolsomico quer...
# 1170       pt      1                        Voce é burra ou é só má fé?
# 1171       pt      1  Mas os canalhas pegaram no pé dele mesmo É rid...
# 1172       pt      1                        Gostosa e burra perfeitinha
# 1173       pt      1  Menina de deus o que que tu tá fumando Você tá...
#
#         COMP_1    COMP_2
# 1169  8.145769  5.025225
# 1170  5.978381  7.721466
# 1171  9.413983  2.585227
# 1172  6.259656  8.087798
# 1173  6.622025  7.321076

# %%
# Visualize the distribution of embeddings with a hover to see the tweets.
fig = px.scatter(
    subset_hs,
    x="COMP_1",
    y="COMP_2",
    hover_data=["Text_Processed"])
fig.show()

# %% [markdown]
# ### Clustering

# %%
# Apply the HDBSCAN algorithm to extract the clusters.

mc_size = 8
m_samples = 3

db_model = HDBSCAN(min_cluster_size=mc_size,
                   min_samples=m_samples,
                   metric="euclidean", 
                   )
db_model.fit(subset_hs.loc[:,["COMP_1", "COMP_2"]])
subset_hs.loc[:, "CLUSTER"] = db_model.labels_
subset_hs.loc[:, "PROBA"] = db_model.probabilities_
# Out:
# /tmp/ipykernel_30810/1278871615.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_30810/1278871615.py:12: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Visualize clusters
plt.figure(figsize=(12,9))
plt.scatter(vecs_umap[:,0], vecs_umap[:,1], alpha=0.7, c=db_model.labels_, s=10)
plt.title(f"Hate Speech in {LANG}\n Min cluster size: {mc_size} | Min samples: {m_samples}")
plt.show()

# %%
# Extract the centroid of each cluster

cl_centroids = {}

for i in sorted(subset_hs["CLUSTER"].unique()):

  cl_centroids[i] = subset_hs[subset_hs["CLUSTER"] == i][["COMP_1", "COMP_2"]].mean().values

centroids_array = np.array(list(cl_centroids.values()))

fig, ax = plt.subplots(figsize=(12,9))
ax.scatter(vecs_umap[:,0], vecs_umap[:,1], s=10, alpha=0.7, c=db_model.labels_)
ax.scatter(centroids_array[:,0], centroids_array[:,1], marker="*", c="red")
for i in cl_centroids:
  ax.annotate(i, cl_centroids.get(i)+np.array([0.1, 0.1]))
plt.show()

# %%
from sklearn.metrics.pairwise import euclidean_distances

N = 5

for i in cl_centroids:
  point = cl_centroids.get(i).reshape(1,-1)
  ix_min_dist = np.argsort(euclidean_distances(point, subset_hs.loc[:, ["COMP_1", "COMP_2"]])).flatten()[:N]
  print(f"Tweets más representativos del cluster {i}")
  print(subset_hs.iloc[ix_min_dist, 
                       subset_hs.columns.get_loc("Text_Processed")].values, "\n")
# Out:
# Tweets más representativos del cluster -1
# ['Reinaldo quem Esse imbecil metido a jornalista de internet Delinquente é a mãe dele que pelo visto não ensinou o que é bom e ruim pra ele'
#  'Chegar a esse ponto de uma carreira e dar uma notícia tão comicamente ingênua nos leva a pensar coisas ou é completamente incompetente Ou é consciente porta voz de golpistas Pq na boa de boa fé uma coisa como essa só se justifica na plena incompetência Nem estagiario!'
#  'Coitada Eu mesmo não conseguiria assistir o programa dela por minutos imagina ela Que fez esta bosta Kkkk'
#  'O cara é uma pessoa arrogante presunçosa usando as supremas palavras do Barroso Você é uma pessoa horrível uma mistura de mal com o atraso e pitadas de psicopatia Esse jornazista está prestando um desserviço aos Pingos nos Is Volta Cris volta n ForaDiogoSchelp'
#  'Volta para Os Pingos nos Is por favor estão destruindo o programa colocar um jornazista horrivel httpst.co/uotiKujl']
#
# Tweets más representativos del cluster 0
# ['Fake Jornalista marrom Loosa rocha Qual quer um não importa Mas é uma vergonha pra nós brasileiros httpst.co/hDOJTaee'
#  'Nação BLUE infelizmente postou uma notícia fake de um jornalista fake inclusive o Chelsea nunca fez proposta pelo Dembele pq estava querendo o Raphinha (esse aqui perdeu para o Barcelona e o Chelsea só consultou o Lewandowski já estava acertado com o Barcelona a meses'
#  'fake de jornalista desculpa amigo estava lendo um bom livro'
#  'Este jornalista é o rei das Fake .'
#  'Índios Fake só no Brasil que tem dessas coisas']
#
# Tweets más representativos del cluster 1
# ['Mano isso aí eles só estão repetindo a fake news daquele jornalista ontem fatos totalmente distorcidos interpretaram a fala do JT totalmente fora da realidade do que foi dito'
#  'Cadê a e outros fact checkers pra carimbar essa fake news aqui E que porra de jornalista é essa que pega uma informação de um blog qualquer não checa a veracidade da informação e publica num jornal como a ?'
#  'Que feio jornalista que feio Só que voces podem mesmo publicar mesmo sendo fake news Nossa como a democracia de vocês é estranha.'
#  'Na ânsia de fazer politicagem da pior qualidade essa “jornalista fez “fake news e ainda acaba de matar a escritora que FEIO EM?'
#  'AVISO A JOVEM PAN ForaDiogoSchelp DEPOIS VOU AGIR BOICOTE A JOVEM PAN DEIXO CLARO DIOGO SCHELP DESPREPARADO COMO JORNALISTA PESSIMO E HISTÓRIA NEM SABE O QUE FOI ORGANIZAÇÃO SOCIAL PUBLICA DO BRASIL MENTE PREGA FAKE NEWS RESUMO INCOMPETENTE PELO SALARIO GANHA']
#
# Tweets más representativos del cluster 2
# ['O problema é você nunca foi um jornalista e sim um ativista político de esquerda.'
#  'Fico perplexo de como um cara que se diz jornalista fazendo fake New O jornalismo sério acabou virou máquina de militância da esquerda httpst.co/XHkKdgZ'
#  'Que coisa horrorosa um reacionário que milita por jair o sombrio e tem a pretensão de se intitular jornalista httpst.co/nxEIDyxYQ'
#  'Eu vi a entresvista e a jornalista só fez pergunta que a esquerda quiz Pelo jeito a militância lá já tá contaminada infelizmente.'
#  'Falou o especialista nKennedy Alencar kkkkkk nDia de setembro ele vai falar que é ato antidemocrático e golpista kkk nEsse jornazista é uma vergonha']
#
# Tweets más representativos del cluster 3
# ['A tia está descontrolada quer dizer descabelada kkkkkkk'
#  'cuidado q ela tá descontrolada'
#  'Descontrolada é vcsó a esquerdalha httpst.co/DpxXfSpN'
#  'Perdoem Acho que ela toma corote com skol beats e fica descontrolada'
#  'A marmita de miliciano tá descontrolada que mimosa!']
#
# Tweets más representativos del cluster 4
# ['Negra jornalista aclamada como âncora aplaudida pela esquerda mas o dindin cabô né Juju Fica tiste não tem a VEJA Folha Estadão Mídia Ninja e até correspondente internacional de O Granma cubano oportunidade não falta'
#  'Sempre tirando as frases dele do contexto Sim minha querida comunista de iphone pois um povo armado jamais será escravizado Vai pra Cuba e pra Venezuela Lá não pode comprar nem feijão quiçá um fuzil!Acorda pra realidade Alice'
#  'Carta de qual democracia seria isso na China ou em Cuba pois se nosso país não tivesse democracia vc nem poderia estar escrevendo essa lorota pra não ser preso pare de achar que o povo é idiota seu jornazista'
#  'Deixem de mimimi Deveriam ter solidariedade sim é com o povo Se não construíssem estádios ao invés de hospitais poderíamos ter melhores condições de saúde hoje se não tivessem investido em um porto em Cuba o de Angra dos Reis poderia não estar definhando junto desempreg'
#  'Liberdade pra Cuba CUBA está já dia em protestos nas ruas pela liberdade e a velha imprensa decadente militante está calada Não querem que o povo saiba que a volta do PT trará o caos httpst.co/qroIBPoRKN']
#
# Tweets más representativos del cluster 5
#  'Percebemos seu lado comunista de tanto que vc critica o gover Mostrou se uma pessoa antissocial intragável por isso não assistimos mais nenhuma programação dessa emissora que faz de tudo pra destruir a família tradicional e seus valores'
#  'Meia verdade O PT fez conciliação Tanto q ajudou teus patrões a bancarem teu salário (gordo demais pra tua competência esquálida Queremos q o PT enfim faça essa distinção somos nós o povo contra a elite escravocrata da qual vcs são os porta vozes e Bozo um ávido bufão.'
#  'Juro que não queria dar palco pra louca mas nao resisti Jogador omisso de opinião vcs reclamam Jogador com opinião formada vcs deturpam de boa se decide aí se é mesmo essa profissão que vc exerce vc quer denegrir mesmo A']
#
# Tweets más representativos del cluster 31
# ['A foto do cara OFERECENDO CLOROQUINA P UMA EMA precisa de fonte Tu é burra p caralho isso sim!'
#  'Foto do flamengo na capa kkkkk É minha filha burrão A piada aqui é você e tu não sabe nem da vida vai saber de política Acorda alice'
#  'A Manu tá tão gorda nessa foto que nem o papel da foto está aguentando pode notar que ele está torto,kkk.'
#  'Recife será reduto de pilantras da esquerda adeus Recife.'
#  'A esquerda é mestre em passar vergonha A vergonha é ainda maior quando a invertida vem com classe em um baixo tom de voz Deixa de mimi mimi mimi mimi mimi mimi mimimmimimiimmimi mimimimimimimi httpst.co/gathNdmlu']
#
# Tweets más representativos del cluster 32
# ['E vc pra lavar a louça suja da comilança do pavê.' 'Todes é meu ovo'
#  'Caralho onde vc fez essas tatuagens No presídio Puta que pariu que coisa feia httpst.co/FaDEibH'
#  'imunda e mentirosa httpst.co/UaIOaHEw'
#  'Essa mulher é uma tenda de uma mentirosa httpst.co/rvlmECjvD']
#
# Tweets más representativos del cluster 33
# ['vc tbm Recife tá fudida Dois escrotos.'
#  'Estimada (sqn datilógrafa vc não consegue interpretar uma brincadeira nem pelo sorriso dele Ou é canalhice Espero que seja apenas burrice sua.'
#  'Vc postou que ele lhe chamou de canalha Ele tá desafiando vc mostrar que ele fez isso E aí vai mostrar ou contar outra mentira sobre ?'
#  'Mamata com dinheiro público.'
#  'Lixo de apresentadora deixei de assistir a pois com uma apresentadora comunista me recuso ao canal .']
#
# Tweets más representativos del cluster 34
# ['Que bonito heim Ciro Daí aparece certas criaturas dos infernos como e outros cobrando a presença do PT Vcs são todos canalhasnunca foram a favor do trabalhador Hipócritas httpst.co/RIEllGbx'
#  'Amélia falando de uma coisa que parecia ser uma coisa decente(assaltante de mãos armadas de repente está coisa aparece anos depois sendo jornazista da rede lixo e se passando por alguma coisa com moral e seus bons costumes Entendeu Eu também não entendi nada'
#  'Né por nada não mais isso me cheira a desespero Oh mulher faz tua campanha de boa zzzz todo mundo já viu isso que sono httpst.co/muxIZjibD'
#  'Agora pode tirar a fantasia de recatada e do lar e voltar a ser a comunistinha de sempre.'
#  'Ainda teve uma outra vagabunda que foi pra CPI usando o palco custeado com nosso dinheiro dizer que não queria escutar respostas Aí Dona ataca Renan Ataca a as vagabundas da saia de gravatas Da não quero respostas']
#
# Tweets más representativos del cluster 35
# ['A Direita asquerosa sempre com esse mimimi da tal da narrativa Toda vez que descobrem as falcatruas dessa gentalha é sempre narrativa da imprensa'
#  'Está na hora de fazer uma reciclagem a interpretação de texto está péssima.'
#  'Apelativa Desde o começo ela chamou de frouxo criança e etc agora tá fazendo a ofendida Esse tipo de narrativa atrapalha quem realmente sofre machismo Coisa feia httpst.co/KhwyRmTfWW'
#  'Você tem dificuldade com interpretação de texto Deve ter sido alfabetizada pelo método Paulo Freire Acha que uma simples constatação é uma ameaça Eu hein Ou é ou se faz Dãã'
#  'Interpretação de texto please.']
#
# Tweets más representativos del cluster 36
# ['É duro hein guerrilheira canalha'
#  'Puta merda Cynara você é canalha demais'
#  'Dizer isso nunca é demais é uma das maiores canalhas da imprensa desse país httpst.co/qFuRtWGlZk'
#  'Ninguém agrediu nenhum policial canalha!' 'Que canalha essa mulher.']
#
# Tweets más representativos del cluster 37
# ['Vai comer alfafa sua Jumenta Seu textinho lixo no UOL só serve pra provar que a esquerda é um lixo Hipócrita babaca Kkkk chora na cama que é lugar quente'
#  'Melhor parte da eleição é varrer esse lixo.'
#  'para de mentir seus lixos se luladrão ganhar ele vai calar a latrina suja de vcs parem de dar tiro no pé bando de hipócritas httpst.co/MjdYKMUP'
#  'Lixo apoiando lixo vai que dá certo' 'Os lixos se juntam sempre']
#
# Tweets más representativos del cluster 38
# ['Coitada Ela vai lá e tira um print da matéria que ela viu e já tem a opinião dela sem base sem fundamento e sem lógica Garota pelo amor né'
#  'Não tenho sororidade com mulher escrota naoooo Nunca tive Nunca terei A pessoa tem q ter caráter Ela q lute com xingamentos q recebe e q distribui p todos!'
#  'Mentirosa Eu confio nas forças armadas Não confio é nessa jornazista e nessa mídia porca.'
#  'Alugada igual a milícia digital com dinheiro público desviado Depois da rachadinha o barato é a vaxinadinha.'
#  'É inacreditável ver essa maluca que nunca trabalhou na vida chegar onde chegou só pode estar torcendo para não ganhar pois se ganhar não sabe o que fazer.']
#
# Tweets más representativos del cluster 39
# ['Retardada no mínimo carimba que é httpst.co/IRsqJaB'
#  'Onde tem um demônio a Marina Silva corre pra abraçar Ainda me pergunto como cai na lábia dessa serva de satanás em e .'
#  'A macacada da bunda branca já está alucinada de raiva Depois do almoço começará a chamar o algoritmo do Google de comunista soviético filho da puta.'
#  'A Cruz Sagrada seja a minha Luz Não seja o dragão o meu guia Retira te satanás Nunca me aconselhes coisas vãs É mau o que tu me ofereces Bebe tu mesmo o teu veneno Amém'
#  'Devem estar debaixo da cama fazendo tranças no suvaco cabeludo.']
#
# Tweets más representativos del cluster 40
# ['Porque insistir em esconder que é comunista Melhor se resolver divez'
#  'Esquece essa mercenaria comunista Aliás manda ela pra Cuba !'
#  'E os comunistas que deliram hahahahah'
#  'Só maluco para votar em dois comunistas podres!'
#  'Tem que esconder a placa de urubus comunistas como você.']
#
# Tweets más representativos del cluster 41
# ['Cheio de índios brancos e de barba httpst.co/fMWSnCnO'
#  'Cheio de índios suíços' 'Nazipreta é foda'
#  'MÔNICA na salada a gente coloca VINAGRE não CACHAÇA'
#  'Essa senhora é muito nojenta!']
#
# Tweets más representativos del cluster 42
# ['O bananinha teve um orgasmo agora'
#  'Expor Martinho colocar em evidência pra milícia carioca que executou Marielle Tem que ser muito escrota.'
#  'Coitada desde então tomando porrada na cara segue o jogo Ela não aprende'
#  'Aí “boa noite tipo “lacrei kkkkkkk figura essa Daniela Se acha um bocado Pena a parcialidade.'
#  'Concordo plenamente foi inconveniente inoportuna Perdeu a chance de ficar calada.']
#
# Tweets más representativos del cluster 43
# ['Cadê aquelas paspalhas do psol a jumenta gov do RN a amante'
#  'Vai trabalhar Demo' 'Vai trabalhar no Exércitotá faltando canhão.'
#  'Vai trabalhar jumenta' 'Vai dormir comunista!']
#
# Tweets más representativos del cluster 44
# ['Mas é claro que a REDE iria apoiar uma comunista de merda tudo farinha do mesmo saco.'
#  'Ah sim claro Pobre Bob Jeff o rei do mensalão Cada uma O povo comendo sopa de osso e a senhoura preocupada com o pobre injustiçado do Bob Jeff Vai lavar uma louça vai maluca.'
#  'Cantanhede é porca suas análises são porcas'
#  'Se tem alguém que é jagunça de macho é a Pessoa sem valor algum!'
#  'Além de cadela pulguenta é analfabeta!']
#
# Tweets más representativos del cluster 45
# ['Cala boca burra Tá passando vergonha infeliz Ate para ser birra tem limites sequelada Analfabetismo é sério sua Hipócritacrita'
#  'Acostumada com uma mamata e acha que todo mundo precisa ser bancado né comunista Sai da bolha Acorda mulher Cai na real o povo quer li ber da de!'
#  'E agora como continuar acompanhando o com uma jornalista tendenciosa que usa de meias palavras pra tentar denegrir um candidato.'
#  'O que esperar de uma analfabeta funcional Vera Magalhães atribui frase de Heráclito ao ex ministro do STF Ayres Britto httpst.co/UJMaLrhfX'
#  'Uma comentarista fracassada que tem tanto ódio no coração que tenta plantar e sai']
#
# Tweets más representativos del cluster 46
# ['Velha decrépita devia tá num asilo.' 'Velha branca rica'
#  'Kkkkkkkkkkkkkkkkkk véia louca esqueceu de tomar o gardenal.'
#  'velha escrota' 'Chora comuna !']
#
# Tweets más representativos del cluster 47
# ['kkkkkk vai aprender a escrever o português corretamente jumenta'
#  'Não fica brava quando o desfile for de canhão vão chamar você a pra servir de bucha kkkkk'
#  'Kkkkk Que mulher ridícula O povo se ferrando no Afeganistão e agora quer bancar a engraçadinha É mais fácil pedir desculpa pela merda que você falou mulher Kkkkk'
#  'Antes gado que jumenta kkkk acéfala inconsequente'
#  'Querida jornalista kkkkk só da esquerda né porque pra mim não passa de uma no Bobona da globo kkkk']
#
# Tweets más representativos del cluster 48
# ['A louca JORNAZISTA matou a Glória Pérez httpst.co/IzlemHgz' 'Que loca'
#  'Outra maluca.' 'Louca.' 'Porca!']
#
# Tweets más representativos del cluster 49
# ['Vai procurar o que fazer maluca Procura uma pia cheia de louça para lavar pode até ser fantasiada de índio!'
#  'Imagina ser paga pra escrever uma porcaria dessa'
